# %%
! pip install pandas-datareader

# %%
import pandas_datareader as web
from datetime import date
from dateutil.relativedelta import relativedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def get_dates(data_window):
    '''
    Returns the start date and end date for given number of years

    Parameters:
    data_window (int): number of years of past data

    Returns:
    start_date (datetime): start date
    end_date (datetime): today's date
    '''
    end_date = pd.to_datetime(date.today())
    start_date = pd.to_datetime(
        date.today() + relativedelta(years=-data_window))

    return start_date, end_date

# %%
data_window = 4 # look at last 4 years of data
start_date, end_date = get_dates(data_window)
stocks = ['AAPL', 'MSFT', 'AMZN', 'FB'] # top 4 SP500 stocks

# %%
# get stock data and store in CSV files

for stock in stocks:
    df = web.DataReader(stock, data_source='yahoo', start=start_date, end=end_date)
    df.to_csv('../data/{}.csv'.format(stock))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-82-8caf9d469a37> in <module>
#       3 for stock in stocks:
#       4     df = web.DataReader(stock, data_source='yahoo', start=start_date, end=end_date)
# ----> 5     df.to_csv('../data/{}.csv'.format(stock))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3400             doublequote=doublequote,
#    3401             escapechar=escapechar,
# -> 3402             storage_options=storage_options,
#    3403         )
#    3404
#
# ...

# %%
# take a look at the data
df.head()
# Out:
# Symbols          AAPL       MSFT        AMZN          FB       AAPL  \
# Attributes  Adj Close  Adj Close   Adj Close   Adj Close      Close
# Date
# 2017-03-13  33.052044  60.897831  854.590027  139.600006  34.799999
# 2017-03-14  33.002182  60.615509  852.530029  139.320007  34.747501
# 2017-03-15  33.351227  60.935478  852.969971  139.720001  35.115002
# 2017-03-16  33.405842  60.831951  853.419983  139.990005  35.172501
# 2017-03-17  33.239635  61.048401  852.309998  139.839996  34.997501
#
# Symbols          MSFT        AMZN          FB       AAPL       MSFT  ...  \
# Attributes      Close       Close       Close       High       High  ...
# Date                                                                 ...
# 2017-03-13  64.709999  854.590027  139.600006  34.857498  65.190002  ...
# 2017-03-14  64.410004  852.530029  139.320007  34.912498  64.550003  ...
# 2017-03-15  64.750000  852.969971  139.720001  35.187500  64.919998  ...
# ...

# %%
# Out:
# Symbols  Attributes  Date
# AAPL     Adj Close   2017-03-13    3.305204e+01
#                      2017-03-14    3.300218e+01
#                      2017-03-15    3.335123e+01
#                      2017-03-16    3.340584e+01
#                      2017-03-17    3.323964e+01
#                                        ...
# FB       Volume      2021-03-05    2.680810e+07
#                      2021-03-08    1.837270e+07
#                      2021-03-09    2.201840e+07
#                      2021-03-10    1.419750e+07
#                      2021-03-11    1.528991e+07
# Length: 24168, dtype: float64
